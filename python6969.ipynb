# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904394-droid/python6969.ipynb/blob/main/python6969.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas=[hall,kit,liv,bed,bath]
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
areas = [hall, kit, "living room", liv, bed, "bathroom", bath]
print(areas)
# Out:
# [11.25, 18.0, 'living room', 20.0, 10.75, 'bathroom', 9.5]

# %%
areas = [hall, kit, "living room", liv, bed, "bathroom", bath]

# %%
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50
house = [["hallway", hall],["kitchen", kit],["living room", liv]]
print(house)
print(type(house))
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0]]
# <class 'list'>

# %% [markdown]
# # Mục mới

# %% [markdown]
# # Mục mới
